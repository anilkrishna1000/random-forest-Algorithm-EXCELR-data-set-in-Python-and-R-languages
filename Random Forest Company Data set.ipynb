# %%
import pandas as pd
import numpy as np

# %%
cd= pd.read_csv("Company_Data.csv")

# %%
cd.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
cd.shape
# Out:
# (400, 11)

# %%
cd.columns
# Out:
# Index(['Sales', 'CompPrice', 'Income', 'Advertising', 'Population', 'Price',
#        'ShelveLoc', 'Age', 'Education', 'Urban', 'US'],
#       dtype='object')

# %%
cd.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# max    191.000000   80.000000   18.000000

# %%
df=pd.DataFrame(cd) # Defining The data frame

# %%
# create dummies for ShelveLoc
dummies = pd.get_dummies(df['ShelveLoc']).rename(columns=lambda x: 'ShelveLoc_' + str(x))
# bring the dummies back into the original dataset
df = pd.concat([df, dummies], axis=1)
print(df)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US  ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium
# 0           17   Yes  Yes              1               0                 0
# 1           10   Yes  Yes              0               1                 0
# 2           12   Yes  Yes              0               0                 1
# 3           14   Yes  Yes              0               0                 1
# 4           13   Yes   No              1               0                 0
# ..         ...   ...  ...            ...             ...               ...
# 395         14   Yes  Yes              0               1                 0
# 396         11    No  Yes              0               0                 1
# 397         18   Yes  Yes              0               0                 1
# 398         12   Yes  Yes              1               0                 0
# 399         16   Yes  Yes              0               1                 0
#
# [400 rows x 14 columns]

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US  ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium
# 0         17   Yes  Yes              1               0                 0
# 1         10   Yes  Yes              0               1                 0
# 2         12   Yes  Yes              0               0                 1
# 3         14   Yes  Yes              0               0                 1
# 4         13   Yes   No              1               0                 0

# %%
df = df.drop('ShelveLoc', 1)

# %%
# create dummies for Urban Column
dummies = pd.get_dummies(df['Urban']).rename(columns=lambda x: 'Urban_' + str(x))
# bring the dummies back into the original dataset
df = pd.concat([df, dummies], axis=1)
print(df)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US  ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  \
# 0     Yes  Yes              1               0                 0         0
# 1     Yes  Yes              0               1                 0         0
# 2     Yes  Yes              0               0                 1         0
# 3     Yes  Yes              0               0                 1         0
# 4     Yes   No              1               0                 0         0
# ..    ...  ...            ...             ...               ...       ...
# 395   Yes  Yes              0               1                 0         0
# 396    No  Yes              0               0                 1         1
# 397   Yes  Yes              0               0                 1         0
# 398   Yes  Yes              1               0                 0         0
# 399   Yes  Yes              0               1                 0         0
#
#      Urban_Yes
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 395          1
# 396          0
# 397          1
# 398          1
# 399          1
#
# [400 rows x 15 columns]

# %%
# create dummies for US Column
dummies = pd.get_dummies(df['US']).rename(columns=lambda x: 'US_' + str(x))
# bring the dummies back into the original dataset
df = pd.concat([df, dummies], axis=1)
print(df)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#     Urban   US  ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  \
# 0     Yes  Yes              1               0                 0         0
# 1     Yes  Yes              0               1                 0         0
# 2     Yes  Yes              0               0                 1         0
# 3     Yes  Yes              0               0                 1         0
# 4     Yes   No              1               0                 0         0
# ..    ...  ...            ...             ...               ...       ...
# 395   Yes  Yes              0               1                 0         0
# 396    No  Yes              0               0                 1         1
# 397   Yes  Yes              0               0                 1         0
# 398   Yes  Yes              1               0                 0         0
# 399   Yes  Yes              0               1                 0         0
#
#      Urban_Yes  US_No  US_Yes
# 0            1      0       1
# 1            1      0       1
# 2            1      0       1
# 3            1      0       1
# 4            1      1       0
# ..         ...    ...     ...
# 395          1      0       1
# 396          0      0       1
# 397          1      0       1
# 398          1      0       1
# 399          1      0       1
#
# [400 rows x 17 columns]

# %%
df = df.drop('Urban', 1)

# %%
df = df.drop('US', 1)

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#    ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0              1               0                 0         0          1
# 1              0               1                 0         0          1
# 2              0               0                 1         0          1
# 3              0               0                 1         0          1
# 4              1               0                 0         0          1
#
#    US_No  US_Yes
# 0      0       1
# 1      0       1
# 2      0       1
# 3      0       1
# 4      1       0

# %%
row_indexes=df[df['Sales']>=10].index

# %%
df.loc[row_indexes,'sales']="yes"

# %%
row_indexes=df[df['Sales']<10].index

# %%
df.loc[row_indexes,'sales']="no"

# %%
df.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#    ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0              1               0                 0         0          1
# 1              0               1                 0         0          1
# 2              0               0                 1         0          1
# 3              0               0                 1         0          1
# 4              1               0                 0         0          1
#
#    US_No  US_Yes sales
# 0      0       1    no
# 1      0       1   yes
# 2      0       1   yes
# 3      0       1    no
# 4      1       0    no

# %%
df = df.drop('Sales', 1)

# %%
colnames = list(df.columns)
colnames
# Out:
# ['CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'Age',
#  'Education',
#  'ShelveLoc_Bad',
#  'ShelveLoc_Good',
#  'ShelveLoc_Medium',
#  'Urban_No',
#  'Urban_Yes',
#  'US_No',
#  'US_Yes',
#  'sales']

# %%
predictors = colnames[:14]
target = colnames[14]

# %%
target
# Out:
# 'sales'

# %%
predictors
# Out:
# ['CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'Age',
#  'Education',
#  'ShelveLoc_Bad',
#  'ShelveLoc_Good',
#  'ShelveLoc_Medium',
#  'Urban_No',
#  'Urban_Yes',
#  'US_No',
#  'US_Yes']

# %%
X = df[predictors]
Y = df[target]
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0          138      73           11         276    120   42         17
# 1          111      48           16         260     83   65         10
# 2          113      35           10         269     80   59         12
# 3          117     100            4         466     97   55         14
# 4          141      64            3         340    128   38         13
# ..         ...     ...          ...         ...    ...  ...        ...
# 395        138     108           17         203    128   33         14
# 396        139      23            3          37    120   55         11
# 397        162      26           12         368    159   40         18
# 398        100      79            7         284     95   50         12
# 399        134      37            0          27    120   49         16
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0                1               0                 0         0          1
# 1                0               1                 0         0          1
# 2                0               0                 1         0          1
# 3                0               0                 1         0          1
# 4                1               0                 0         0          1
# ..             ...             ...               ...       ...        ...
# 395              0               1                 0         0          1
# 396              0               0                 1         1          0
# 397              0               0                 1         0          1
# 398              1               0                 0         0          1
# 399              0               1                 0         0          1
#
#      US_No  US_Yes
# 0        0       1
# 1        0       1
# 2        0       1
# 3        0       1
# 4        1       0
# ..     ...     ...
# 395      0       1
# 396      0       1
# 397      0       1
# 398      0       1
# 399      0       1
#
# [400 rows x 14 columns]

# %%
X
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0          138      73           11         276    120   42         17
# 1          111      48           16         260     83   65         10
# 2          113      35           10         269     80   59         12
# 3          117     100            4         466     97   55         14
# 4          141      64            3         340    128   38         13
# ..         ...     ...          ...         ...    ...  ...        ...
# 395        138     108           17         203    128   33         14
# 396        139      23            3          37    120   55         11
# 397        162      26           12         368    159   40         18
# 398        100      79            7         284     95   50         12
# 399        134      37            0          27    120   49         16
#
#      ShelveLoc_Bad  ShelveLoc_Good  ShelveLoc_Medium  Urban_No  Urban_Yes  \
# 0                1               0                 0         0          1
# 1                0               1                 0         0          1
# 2                0               0                 1         0          1
# 3                0               0                 1         0          1
# 4                1               0                 0         0          1
# ..             ...             ...               ...       ...        ...
# 395              0               1                 0         0          1
# 396              0               0                 1         1          0
# 397              0               0                 1         0          1
# 398              1               0                 0         0          1
# 399              0               1                 0         0          1
#
#      US_No  US_Yes
# 0        0       1
# 1        0       1
# 2        0       1
# 3        0       1
# 4        1       0
# ..     ...     ...
# 395      0       1
# 396      0       1
# 397      0       1
# 398      0       1
# 399      0       1
#
# [400 rows x 14 columns]

# %%
Y
# Out:
# 0       no
# 1      yes
# 2      yes
# 3       no
# 4       no
#       ...
# 395    yes
# 396     no
# 397     no
# 398     no
# 399     no
# Name: sales, Length: 400, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_jobs=2,oob_score=True,n_estimators=15,criterion="entropy")

# %%
rf.fit(X,Y) # Fitting RandomForestClassifier model from sklearn.ensemble 
rf.estimators_ #
# Out:
# [DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=159823017, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2098053145, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=843802452, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2070045810, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=339706968, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=121129418, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=641835681, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=22552961, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1999208005, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1279614926, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1894343220, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1779370642, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=2126152604, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=407482446, splitter='best'),
#  DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                         max_features='auto', max_leaf_nodes=None,
#                         min_impurity_decrease=0.0, min_impurity_split=None,
#                         min_samples_leaf=1, min_samples_split=2,
#                         min_weight_fraction_leaf=0.0, presort=False,
#                         random_state=1785928904, splitter='best')]

# %%
rf.classes_ # class labels (output)
rf.n_classes_ # Number of levels in class labels
# Out:
# 2

# %%
rf.n_features_  # Number of input features in model 14 here.
# Out:
# 14

# %%
rf.n_outputs_ # Number of outputs when fit performed
# Out:
# 1

# %%
rf.oob_score_  # 0.84
# Out:
# 0.84

# %%
rf.predict(X)
# Out:
# array(['no', 'yes', 'yes', 'no', 'no', 'yes', 'no', 'yes', 'no', 'no',
#        'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'no',
#        'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no',
#        'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes', 'no',
#        'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'no', 'yes', 'yes', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no',
#        'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'no', 'no',
#        'no', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'no',
#        'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'yes', 'no', 'no',
#        'no', 'yes', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no',
#        'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'no', 'no',
#        'no', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes',
#        'no', 'no', 'no', 'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no', 'no', 'no', 'no',
#        'no', 'no', 'no', 'yes', 'no', 'no', 'no', 'no'], dtype=object)

# %%
df['rf_pred'] = rf.predict(X)

# %%
cols = ['rf_pred','sales']

# %%
cols
# Out:
# ['rf_pred', 'sales']

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(df['sales'],df['rf_pred'])
# Out:
# array([[321,   0],
#        [  1,  78]], dtype=int64)
